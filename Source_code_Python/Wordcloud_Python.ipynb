# %%
#Loading the required libaries
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
#from nltk.stem import PorterStemmer
import numpy as np
import pandas as pd
import os
import re
import warnings
from sys import exit
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
#from nltk.corpus import stopwords
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("Clean_Twitter_data.csv")
twitter_data = df[['Tweet_lemmatized']]

# %%
twitter_data
# Out:
#                                        Tweet_lemmatized
# 0     ['ufawe', 'love', 'hearing', 'current', 'teamu...
# 1     ['health', 'heart', 'see', 'make', 'difference...
# 2     ['rt', 'nasw', 'nasw', 'excited', 'kick', 'stu...
# 3     ['rt', 'mickfinnegan', 'told', 'couldnt', 'dif...
# 4     ['socialwork', 'childwelfare', 'workforcehealt...
# ...                                                 ...
# 1811  ['igiftlife', 'socialwork', 'igiftlife', 'soci...
# 1812  ['rt', 'sasoscotland', 'sasowebinar', 'impact'...
# 1813  ['brilliant', 'news', 'socialwork', 'guernsey'...
# 1814  ['fantastic', 'opportunity', 'join', 'workforc...
# 1815  ['ngo', 'nonprofit', 'education', 'covid', 'vo...
#
# [1816 rows x 1 columns]

# %%
stopwords = set(STOPWORDS)
letters_only = re.sub("[^a-zA-Z]+",  # Search for all non-letters

                         " ",          # Replace all non-letters with spaces

str(twitter_data['Tweet_lemmatized']))

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(letters_only)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
#Comparing Countvectorizer and Tfidf Vectorizer

# %%
#CountVectorizer
CV=CountVectorizer(input='content',
                      stop_words='english',
                      #decode_error='ignore'
                      )
The_DTM_CV=CV.fit_transform(twitter_data['Tweet_lemmatized'])
TheColumnNames_CV=CV.get_feature_names()

# %%
#regex module
import re

pattern = r'[0-9]'

# Match all digits in the string and replace them with an empty string
New_TheColumnNames = re.sub(pattern, '', str(TheColumnNames_CV))

#print(New_TheColumnNames)

# %%
#print("The vocabulary is:",TheColumnNames,"\n\n")
#The second step is to use pandas to create data frames
The_DF=pd.DataFrame(The_DTM.toarray(),columns=New_TheColumnNames)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-1f8f4e37a969> in <module>
#       1 #print("The vocabulary is:",TheColumnNames,"\n\n")
#       2 #The second step is to use pandas to create data frames
# ----> 3 The_DF=pd.DataFrame(The_DTM.toarray(),columns=New_TheColumnNames)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     556                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     557             else:
# --> 558                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     559
#     560         # For data is list-like, or Iterable (will consume into list)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     204
#     205     # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 206     index, columns = _get_axes(
#     207         values.shape[0], values.shape[1], index=index, columns=columns
#     208     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _get_axes(N, K, index, columns)
#     464         columns = ibase.default_index(K)
#     465     else:
# --> 466         columns = ensure_index(columns)
#     467     return index, columns
#     468
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    5915             index_like = copy_func(index_like)
#    5916
# -> 5917     return Index(index_like)
#    5918
#    5919
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     370
#     371         elif data is None or is_scalar(data):
# --> 372             raise cls._scalar_data_error(data)
#     373         elif hasattr(data, "__array__"):
#     374             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, "['aachen', 'aarey', 'aaron', 'ab', 'abi', 'able', 'aboutchesapeake', 'absence', 'absolute', 'abt', 'abundpev', 'abuse', 'abuseencouragement', 'ac', 'academic', 'academictwitter', 'academy', 'acampanin', 'accept', 'accepted', 'accepting', 'access', 'accomplished', 'according', 'account', 'achieve', 'acma', 'acquired', 'act', 'action', 'actioncp', 'actively', 'activity', 'actor', 'actually', 'acute', 'ad', 'adalah', 'adani', 'adapted', 'add', 'addams', 'addictionrecovery', 'adding', 'address', 'addressing', 'adelaide', 'adem', 'adhd', 'adolescent', 'adoption', 'adoptive', 'adult', 'advance', 'advanced', 'advantage', 'adve', 'adventure', 'adventuretherapy', 'advert', 'advertising', 'advice', 'adviser', 'advocacy', 'advocate', 'advocating', 'aest', 'affair', 'affe', 'affect', 'affected', 'affordable', 'afghanistan', 'afrazerwicks', 'afribuddies', 'afspnational', 'afternoon', 'againuf', 'agarwal', 'age', 'ageappropriate', 'aged', 'agency', 'agenda', 'aging', 'ago', 'agosto', 'agree', 'agreed', 'ahead', 'ai', 'aic', 'aid', 'aidanauthor', 'aim', 'aimz', 'aimzfoundation', 'airadgpwr', 'airahmedabad', 'akali', 'akhirkyun', 'akron', 'al', 'alarming', 'alarmingly', 'albeit', 'alcoatesmbe', 'alcohol', 'alert', 'alex', 'alexandrazannis', 'alexisglen', 'alexochssw', 'alfarero', 'alice', 'align', 'aligned', 'alike', 'alison', 'alisonleary', 'allaboutpaperwork', 'allceus', 'alle', 'alliance', 'allied', 'allocation', 'alongside', 'alumna', 'alumnus', 'alwaystoday', 'amanda', 'amandagrenier', 'amardeepkaushal', 'amartinezarias', 'amazing', 'ambani', 'ambassador', 'ambulance', 'america', 'american', 'americorps', 'amidst', 'amltaylor', 'ammo', 'amnoon', 'amp', 'amphow', 'amplifying', 'anak', 'anakanak', 'analysis', 'analyst', 'anand', 'anderen', 'andha', 'andor', 'andrewgambrill', 'angelou', 'aniketsunny', 'anikulapo', 'anil', 'animal', 'animation', 'anjanafdn', 'anna', 'annabhau', 'annakshetram', 'annasesa', 'anne', 'annie', 'anniversary', 'announce', 'announcement', 'annual', 'anthony', 'anthropology', 'antiracist', 'antisemitism', 'anxiety', 'aocpptweet', 'ap', 'apa', 'apart', 'apcsw', 'app', 'appealing', 'appearance', 'appeared', 'application', 'applied', 'apply', 'applying', 'appointed', 'appointment', 'appreciated', 'appreciation', 'apprentice', 'approach', 'april', 'arabia', 'arbaaz', 'archana', 'archived', 'area', 'arelato', 'argues', 'arhhhghhhhhhhhhhggghhhhhhhhhh', 'arianecritchley', 'arlington', 'arnav', 'arra', 'arrived', 'arrowandthesong', 'art', 'article', 'artifac', 'artist', 'artscibgsu', 'aruesccam', 'asaswei', 'asesinadas', 'asesinado', 'asfa', 'asheville', 'ashleytoomuch', 'ashsplace', 'ashwinityagibjp', 'aside', 'asked', 'asks', 'asktheexpert', 'aspect', 'ass', 'assemble', 'assessing', 'assessment', 'assessor', 'asset', 'assignment', 'assist', 'assistance', 'assistant', 'assisteddecisionmaking', 'associate', 'association', 'aswb', 'asye', 'atdireland', 'atrium', 'attainable', 'attempted', 'attend', 'attended', 'attendee', 'attending', 'attention', 'attest', 'attitude', 'au', 'audiobook', 'august', 'auspicious', 'aussocialworkj', 'austerity', 'australian', 'authority', 'autisme', 'autismus', 'autist', 'avail', 'available', 'avoid', 'award', 'aware', 'awareness', 'awarenessendsbullying', 'away', 'awesome', 'awhadspeaks', 'ayea', 'ayu', 'ayuda', 'ayudaadomicil', 'ayuvanshfounda', 'az', 'azietesfai', 'baby', 'bachelor', 'background', 'backtolearning', 'backtoschool', 'bad', 'bag', 'baldauf', 'banasthaliuufa', 'bandmaferde', 'bandra', 'bank', 'bar', 'barbarambritton', 'barnes', 'barrier', 'base', 'based', 'basic', 'basw', 'baswstudents', 'baswuk', 'bathspauni', 'bauff', 'bayad', 'bc', 'bcsocialworkers', 'beate', 'beautiful', 'beauty', 'bec', 'becau', 'beddoee', 'begin', 'beginning', 'begun', 'behavior', 'behavioral', 'behavioralhealth', 'behindwoods', 'behindwoodsmemes', 'beirut', 'believe', 'bell', 'belo', 'belowu', 'beneficiary', 'benefit', 'bengal', 'benorden ...

# %%
The_DF = The_DF.filter(regex='^\D')

# %%
The_DF.to_csv("DTM_CV.csv")

# %%
#TfidfVectorizer
TF = TfidfVectorizer(stop_words='english')
The_DTM_TFidf = TF.fit_transform(twitter_data['Tweet_lemmatized'])
TheColumnNames_TF=TF.get_feature_names()

# %%
#New_TheColumnNames_2 = re.sub(pattern, '', str(TheColumnNames_TF))

# %%
The_DF_TF=pd.DataFrame(The_DTM_TFidf.toarray(),columns=TheColumnNames)

# %%
The_DF_TF = The_DF_TF.filter(regex='^\D')

# %%
The_DF_TF.to_csv("DTM_TF.csv")

# %%
#Kmeans for K = 3
km = KMeans(n_clusters=3)
km.fit(The_DTM_CV)
# Out:
# KMeans(n_clusters=3)

# %%
pca = PCA(n_components=2, random_state=2)
reduced_features = pca.fit_transform(The_DTM_CV.toarray())

# reduce the cluster centers to 2D\
reduced_cluster_centers = pca.transform(km.cluster_centers_)

# %%
from matplotlib.pyplot import figure

figure(figsize=(10, 12), dpi=80)
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=km.predict(The_DTM_CV))
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='r')

# %%
#Kmeans for K = 5
km = KMeans(n_clusters=5)
km.fit(The_DTM_CV)
# Out:
# KMeans(n_clusters=5)

# %%
pca = PCA(n_components=2, random_state=2)
reduced_features = pca.fit_transform(The_DTM_CV.toarray())

# reduce the cluster centers to 2D\
reduced_cluster_centers = pca.transform(km.cluster_centers_)

# %%
from matplotlib.pyplot import figure

figure(figsize=(10, 12), dpi=80)
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=km.predict(The_DTM_CV))
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='r')

# %%
#Kmeans for K = 8
km = KMeans(n_clusters=8)
km.fit(The_DTM_CV)
# Out:
# KMeans()

# %%
pca = PCA(n_components=2, random_state=2)
reduced_features = pca.fit_transform(The_DTM_CV.toarray())

# reduce the cluster centers to 2D\
reduced_cluster_centers = pca.transform(km.cluster_centers_)

# %%
from matplotlib.pyplot import figure

figure(figsize=(10, 12), dpi=80)
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=km.predict(The_DTM_CV))
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='r')
